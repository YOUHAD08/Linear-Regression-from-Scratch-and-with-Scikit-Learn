# %%
import numpy as np
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split

# %%
np.random.seed(33)
data_lenght=300
coefficient, intercept=5, 10
X=np.random.rand(data_lenght)*100
Noise=np.random.rand(data_lenght)*200
Y=coefficient*X + intercept + Noise

# %%
plt.scatter(X,Y)
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.show()

# %%
learning_rate = 0.0001
number_of_iterations = 1400
coeff, interc = 0, 2
X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.2, random_state=33)
n=len(X_train)

# %%
plt.scatter(X_train, y_train, color='#1f77b4', alpha=0.8, edgecolor='k', label='Training Data')
plt.scatter(X_test, y_test, color='#d62728', alpha=0.8, edgecolor='k', label='Test Data')
plt.title('Training vs Test Data', fontsize=14)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
error=[]
for k in range(number_of_iterations):
    # print(f'itiration : {k} --- Coeff : {coeff} --- interc: {interc}')
    Y_hate= coeff*X_train + interc
    error.append(np.mean((Y_hate - y_train) ** 2))
    dcoeff=-(2/n)* np.sum(X_train*(y_train - Y_hate))
    dinterc=-(2/n)* np.sum(y_train - Y_hate)
    coeff=coeff-learning_rate*dcoeff
    interc=interc-learning_rate*dinterc

Y_hate=coeff*X_train+interc
print(f'Predicetd values : \n {Y_hate}')
print(f'\n--------------------\n')
print(f'Coeff : {coeff} --- interc: {interc}')
print(f'\n--------------------\n')
print(f'Error : \n {np.array(error)}')
# Out:
# Predicetd values :
#  [622.3069262  252.1990475  341.52939691 280.30249375 201.07144282
#  432.3872581  303.33284162  46.57817267 550.92094489 167.79586387
#   34.35384587 454.7913726  561.96146352 239.54455127  29.38717722
#  427.81648367 264.41942332 241.46318063 354.40512211  23.45106176
#  141.6965521   97.01112958 318.83437923 190.04713217 186.19107145
#   21.50807044  91.67159899 391.41919173 652.59863072 552.55808886
#  218.27842785 592.22056267 537.45635418 199.81075652 380.19655307
#  559.032844    89.90627902 388.4085037  354.33039512 127.17277211
#  654.80035209 381.17349455 437.05966917 312.07289449 654.5089693
#  437.47493165 474.3625644  483.32825503 106.47905204 381.25954433
#  512.4783308  131.47194824 468.84643494 105.34638774 141.61343013
#  627.70619227 164.30686024 273.17191565  11.90201318 223.35976395
#  432.74245181 376.54806273 228.245126   104.9290412  570.78805181
#  117.08249821 569.63077275 124.14992723 549.84923554 317.55483018
#  305.80323131 527.88294639 659.49356137 458.47253718 292.62246932
#  348.06331951  35.19640072 121.88892427 537.9282469  254.06535093
#  490.933935    27.56355785 262.87861315 555.12852768 123.66797957
#  522.73004182 503.64441128 417.10683475 337.80559099 242.27609205
#  520.79746683 534.80085555 374.86411157 328.11342112  23.00405947
#  653.3014395   56.24866933 398.54128636 645.86647626 488.19911222
#  647.87378475 580.46352147 175.53664716 316.20566871 645.18735992
#  272.15993954 520.88265081  62.14269683 598.42668648 214.62063991
#  529.66103557 183.00753944 570.2631592  229.51060774 511.59391726
#  422.0121033  116.98265669 343.53873983 233.52167249 482.38489447
#  465.90598513 294.09540905 404.1777204  264.14521362 278.68230796
#  286.00210099 371.31130565 184.64075341 185.82268876 477.79302034
#   31.96688534 271.68937064 559.44507418 289.27394636 400.13716327
#  269.49748791 172.05858553 644.18419595 131.06926323 543.41355553
#  180.24712864 475.68271678 233.80188251 118.49347498 232.85851827
#  623.7682469   90.68415538 290.50657195 116.38573589 143.7036746
#  401.91858367 210.23837253  23.85281617 642.67231375 466.58824558
#  354.88031348  30.87563087 305.04911048 588.76314804 457.65387497
#  356.65883393 276.42997427  68.30077465 515.40786887 289.79064576
#  449.74255182 114.68403055 394.82641137 285.16620488 503.94363493
#   41.17259    289.66855563 289.75662308 612.66623022 239.78071786
#   63.22751335 172.54333666 599.1010326  157.03276581 428.43745147
#  343.53018485 610.03899056 434.05360718  43.02436072 642.44726059
#  534.43049678 640.74519813 247.06958847 512.42529289 256.83093017
#  407.45495758 479.84344659 289.38479553 275.51221388 412.03469264
#  250.77057572 373.41408398  99.44903227  98.03829863 617.61370595
#  488.88771719 308.09007889 266.21789052 336.96005787 559.00200157
#  170.50665883 633.19499002 270.50814816  41.68375955 182.26972651
#  643.66632245 620.81523418 320.57126758 115.72938342 377.9116638
#  633.0510608  597.0721281  566.02069105 103.23845649 106.06207452
#  460.56277594 585.59561301 403.85380621  30.53371977 508.94720162
#  482.90469783 250.82966066 249.51694209 547.00418016 226.75717139
#  356.99674028 267.15465104 299.99736879 631.87343716 133.12885655
#  358.80912331  45.33425926 593.84357131 459.73923939 481.207434  ]
#
# --------------------
#
# Coeff : 6.53441666357553 --- interc: 10.15646487879462
#
# --------------------
#
# Error :
#  [156876.74622751  23054.99603505   8945.41348474 ...   6820.2535208
#    6819.94373561   6819.63397998]

# %%
fig, axs = plt.subplots(1, 2,figsize=(20, 6))

axs[0].scatter(X_train, y_train, color='#1f77b4', label='Training Data', alpha=0.7, edgecolor='k')
axs[0].scatter(X_test, y_test, color='#ff7f0e', label='Test Data', alpha=0.7, edgecolor='k')
axs[0].plot(X_train, Y_hate, color='#2ca02c', linewidth=2.5, label='Trained Model')
axs[0].set_title('Linear Regression Model Fit', fontsize=14)
axs[0].set_xlabel('X values')
axs[0].set_ylabel('Y values')
axs[0].legend()
axs[0].grid(True, linestyle='--', alpha=0.5)

axs[1].plot(np.arange(number_of_iterations), np.array(mse), color='black', label='Mean Square Error', alpha=0.8)
axs[1].set_title('Mean Squared Error over Iterations', fontsize=14)
axs[1].set_xlabel('Iterations')
axs[1].set_ylabel('MSE')
axs[1].legend()
axs[1].grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
Y_hate=coeff*X_test+interc
MSE=1/n* np.sum((Y_hate-y_test)**2)
print(f'Mean Square Error of this Model is : {MSE}')
# Out:
# Mean Square Error of this Model is : 1099.347916484073
